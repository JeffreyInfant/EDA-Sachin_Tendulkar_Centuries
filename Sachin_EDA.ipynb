# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
st=pd.read_csv('/content/Sachin-Tendulkar-All-International-Cricket-Centuries.csv')

# %% [markdown]
# ##Exploration

# %%
st.head()
# Out:
#    No.  Score        Against  Position  Innings  \
# 0    1  119*         England         6        4
# 1    2   148*      Australia         6        2
# 2    3    114      Australia         4        2
# 3    4    111   South Africa         4        2
# 4    5    165        England         4        1
#
#                                 Venue Ground       Date Result
# 0            Old Trafford, Manchester   Away  09-Aug-90  Drawn
# 1       Sydney Cricket Ground, Sydney   Away  02-Jan-92  Drawn
# 2                  WACA Ground, Perth   Away  01-Feb-92   Lost
# 3     Wanderers Stadium, Johannesburg   Away  26-Nov-92  Drawn
# 4  M. A. Chidambaram Stadium, Chennai   Home  11-Feb-93    Won

# %%
st.tail()
# Out:
#     No. Score        Against  Position  Innings  \
# 95   96  111*   South Africa         5        3
# 96   97   146   South Africa         4        2
# 97   98   120        England         2        1
# 98   99   111   South Africa         2        1
# 99  100   114     Bangladesh         2        1
#
#                                      Venue Ground       Date Result
# 95              SuperSport Park, Centurion   Away  16-Dec-10   Lost
# 96      Newlands Cricket Ground, Cape Town   Away  02-Jan-11  Drawn
# 97       M. Chinnaswamy Stadium, Bangalore   Home  27-Feb-11   Tied
# 98                     VCA Stadium, Nagpur   Home  12-Mar-11   Lost
# 99  Sher-e-Bangla National Stadium, Mirpur   Away  16-Mar-12   Lost

# %%
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No.       100 non-null    int64
#  1   Score     100 non-null    object
#  2   Against   100 non-null    object
#  3   Position  100 non-null    int64
#  4   Innings   100 non-null    int64
#  5   Venue     100 non-null    object
#  6   Ground    100 non-null    object
#  7   Date      100 non-null    object
#  8   Result    100 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 7.2+ KB

# %%
st.describe()
# Out:
#               No.    Position     Innings
# count  100.000000  100.000000  100.000000
# mean    50.500000    3.140000    1.630000
# std     29.011492    1.206213    0.786952
# min      1.000000    1.000000    1.000000
# 25%     25.750000    2.000000    1.000000
# 50%     50.500000    4.000000    1.000000
# 75%     75.250000    4.000000    2.000000
# max    100.000000    6.000000    4.000000

# %%
st.isnull().sum()
# Out:
# No.         0
# Score       0
# Against     0
# Position    0
# Innings     0
# Venue       0
# Ground      0
# Date        0
# Result      0
# dtype: int64

# %%
st.shape
# Out:
# (100, 9)

# %%
st.columns
st['Score']
# Out:
# 0     119*
# 1      148*
# 2       114
# 3       111
# 4       165
#       ...
# 95     111*
# 96      146
# 97      120
# 98      111
# 99      114
# Name: Score, Length: 100, dtype: object

# %% [markdown]
# ##DATA CLEANING

# %%
st['Score']=st['Score'].str.replace('*','',regex=False).astype(int)

# %%
st['Score']
# Out:
# 0     119
# 1     148
# 2     114
# 3     111
# 4     165
#      ...
# 95    111
# 96    146
# 97    120
# 98    111
# 99    114
# Name: Score, Length: 100, dtype: int64

# %%
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No.       100 non-null    int64
#  1   Score     100 non-null    int64
#  2   Against   100 non-null    object
#  3   Position  100 non-null    int64
#  4   Innings   100 non-null    int64
#  5   Venue     100 non-null    object
#  6   Ground    100 non-null    object
#  7   Date      100 non-null    object
#  8   Result    100 non-null    object
# dtypes: int64(4), object(5)
# memory usage: 7.2+ KB

# %%
st.drop('Venue',axis=1,inplace=True)

# %%
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No.       100 non-null    int64
#  1   Score     100 non-null    int64
#  2   Against   100 non-null    object
#  3   Position  100 non-null    int64
#  4   Innings   100 non-null    int64
#  5   Ground    100 non-null    object
#  6   Date      100 non-null    object
#  7   Result    100 non-null    object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
st[st['Against'].str.startswith('')]
# Out:
#     No.  Score        Against  Position  Innings Ground       Date Result
# 0     1    119        England         6        4   Away  09-Aug-90  Drawn
# 1     2    148      Australia         6        2   Away  02-Jan-92  Drawn
# 2     3    114      Australia         4        2   Away  01-Feb-92   Lost
# 3     4    111   South Africa         4        2   Away  26-Nov-92  Drawn
# 4     5    165        England         4        1   Home  11-Feb-93    Won
# ..  ...    ...            ...       ...      ...    ...        ...    ...
# 95   96    111   South Africa         5        3   Away  16-Dec-10   Lost
# 96   97    146   South Africa         4        2   Away  02-Jan-11  Drawn
# 97   98    120        England         2        1   Home  27-Feb-11   Tied
# 98   99    111   South Africa         2        1   Home  12-Mar-11   Lost
# 99  100    114     Bangladesh         2        1   Away  16-Mar-12   Lost
#
# [100 rows x 8 columns]

# %%
st[st['Against'].str.strip()=='']
# Out:
# Empty DataFrame
# Columns: [No., Score, Against, Position, Innings, Ground, Date, Result]
# Index: []

# %%
st[st['Against'].str.startswith(' ')]
# Out:
#     No.  Score        Against  Position  Innings Ground       Date Result
# 0     1    119        England         6        4   Away  09-Aug-90  Drawn
# 1     2    148      Australia         6        2   Away  02-Jan-92  Drawn
# 2     3    114      Australia         4        2   Away  01-Feb-92   Lost
# 3     4    111   South Africa         4        2   Away  26-Nov-92  Drawn
# 4     5    165        England         4        1   Home  11-Feb-93    Won
# ..  ...    ...            ...       ...      ...    ...        ...    ...
# 95   96    111   South Africa         5        3   Away  16-Dec-10   Lost
# 96   97    146   South Africa         4        2   Away  02-Jan-11  Drawn
# 97   98    120        England         2        1   Home  27-Feb-11   Tied
# 98   99    111   South Africa         2        1   Home  12-Mar-11   Lost
# 99  100    114     Bangladesh         2        1   Away  16-Mar-12   Lost
#
# [100 rows x 8 columns]

# %% [markdown]
# ##ANALYSIS

# %%
st['Against'] = st['Against'].str.strip()

Pak=st[(st['Score']>=100) & (st['Against']=='Pakistan')]
Pak.shape[0]
# Out:
# 7

# %%
Aus=st[(st['Score']>=100) & (st['Against']=='Australia')]
Aus.shape[0]
# Out:
# 20

# %%
SA=st[(st['Score']>=100) & (st['Against']=='South Africa')]
SA.shape[0]
# Out:
# 12

# %%
WI=Aus=st[(st['Score']>=100) & (st['Against']=='West Indies')]
WI.shape[0]
# Out:
# 7

# %%
Bang=st[(st['Score']>=100) & (st['Against']=='Bangladesh')]
Bang.shape[0]
# Out:
# 6

# %%
SL=st[(st['Score']>=100) & (st['Against']=='Sri Lanka')]
SL.shape[0]
# Out:
# 17

# %%
NZ=st[(st['Score']>=100) & (st['Against']=='New Zealand')]
NZ.shape[0]
# Out:
# 9

# %%
cc=st['Against'].value_counts()  #century counts against each team
cc
# Out:
# Against
# Australia       20
# Sri Lanka       17
# South Africa    12
# England          9
# New Zealand      9
# Zimbabwe         8
# West Indies      7
# Pakistan         7
# Bangladesh       6
# Kenya            4
# Namibia          1
# Name: count, dtype: int64

# %% [markdown]
# #Total scores more than 100

# %%
mth=st[(st['Score'])>100]

# %%
mth.shape[0]
# Out:
# 92

# %%
hisc=st[(st['Score'])>150]
hisc.shape[0]
# Out:
# 25

# %% [markdown]
# #Centuries On Position

# %%
st['Position'].value_counts()
# Out:
# Position
# 4    48
# 2    40
# 1     5
# 5     5
# 6     2
# Name: count, dtype: int64

# %% [markdown]
# ## Centuries in Winning Cause

# %%
winm=st[(st['Score']>100) & (st['Result']=='Won')]

if winm.shape[0]:
   print(winm.shape[0])
# Out:
# 49

# %% [markdown]
# ##Venues
#
# ```
# # home neutral away centuries
# ```

# %%
def Venue():
    home=st[(st['Score']>=100) & (st['Ground']=='Home')]
    print(home.shape[0],'- Home Venue')
    away=st[(st['Score']>=100) & (st['Ground']=='Away')]
    print(away.shape[0],'- Away Venue')
    neutral=st[(st['Score']>=100) & (st['Ground']=='Neutral')]
    print(neutral.shape[0],'- Neutral Venue')
Venue()
# Out:
# 42 - Home Venue
# 41 - Away Venue
# 17 - Neutral Venue

# %% [markdown]
# ##Visualization

# %%
sns.scatterplot(x='Score',y='Against',hue='Against',data=st)
plt.title("SCORES AGAINST EACH COUNTRIES")
plt.figure(figsize=(13,28))
plt.show()

# %%
cc.plot(kind='bar', figsize=(8, 5), color='cyan')
plt.xlabel('Countries')
plt.ylabel('Centuries')
plt.title("CENTURIES AGAINST EACH COUNTRIES")
plt.show()

# %% [markdown]
# ##INSIGHTS
#
# Tendulkar had hit
#
# *   *7 centuries vs Pakistan*
# *   *20 centuries vs Australia*
# *   *17 centuries vs Sri Lanka*
# *   *12 centuries vs South Africa*
# *   *9 centuries vs England*
# *   *7 centuries vs West Indies*
# *   *9 centuries vs New Zealand*
#
# Tendulkar has
#
# *  *5 centuries while opening at 1st slot*
# *   *40 centuries while opening at 2nd slot*
# *   *48 centuries while opening at 4th slot*
# *  *5 centuries while opening at 5th slot*
# *  *2 centuries while opening at 6th slot*
#
# Tendulkar scored
# *  *42 centuries at Home Venues*
# *  *41 centuries at Away Venues*
# *  *17 centuries at Neutral Venues*

# %% [markdown]
# # **SUMMARY**
#
#
#
# *   **Tendulkar is more comfortable at #4 position where his centuries are far better than other positions.Only batting at #2 comes closer.**
# *   **He has more centuries against Australia which is 20% of his total centuries which shows he loves playing against Australia.Next best being Sri Lanka.**
#
# *  **He has slighter edge on Home venues than Away venues though not bigger one.**
# *   **49 out of his 100 100s resulted in winning Cause.**
# *   **He scored beyond 150 for 25 times.**
